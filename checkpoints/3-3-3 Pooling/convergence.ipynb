# %%
from game import World, Sender, Receiver
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import imageio.v2 as imageio
from IPython.display import HTML
from time import time
import os

# %%
def early_stop(epochs, rewards, threshold=0.95):
    return np.sum(rewards[-epochs:]) / epochs > threshold

# %%
def make_gif(filename_base, epochs, seed):
    images = []
    nm = filename_base.split('-')[-1]
    for filename in [f'images/{nm}_{i}.png' for i in range(epochs) if i % 25 == 0]:
        images.append(imageio.imread(filename))
    if not os.path.exists(f'gifs/{seed}'):
        os.mkdir(f'gifs/{seed}')
    imageio.mimsave(f'gifs/{seed}/{filename_base}.gif', images, fps=10)

# %%
def stress(n, epochs, states, signals, actions, initial_weights):
    found = False
    num_found = 0
    for _ in range(n):
        seed = np.floor(time()).astype(int)
        W, S, R = World(states, seed), Sender(states, signals, initial_weights), Receiver(signals, actions, initial_weights)
        past_rewards = 0
        history = []
        stopped = False
        # stopped_at = -1
        for epoch in range(epochs):
            stimulus = W.get_state()
            signal = S.get_signal(stimulus)
            action = R.get_action(signal)
            reward = W.evaluate(action)
            past_rewards += reward
            S.update(reward)
            R.update(reward)

            if epoch % 25 == 0:
                plt.tight_layout(pad=0)
                plot = sns.heatmap(
                    # np.exp(R.action_weights) /
                    # np.exp(R.action_weights).sum(axis=0),
                    R.action_weights / R.action_weights.sum(axis=0),
                    square=True, cbar=False, annot=True, fmt='.1f'
                ).get_figure()
                plt.xlabel('messages')
                plt.ylabel('actions')
                plt.title(f'Receiver\'s weights, rollout {epoch}')
                plt.savefig(f"images/receiver_{epoch}.png")
                plt.clf()

                plot = sns.heatmap(
                    # np.exp(S.signal_weights) /
                    # np.exp(S.signal_weights).sum(axis=0),
                    S.signal_weights / S.signal_weights.sum(axis=0),
                    square=True, cbar=False, annot=True, fmt='.1f'
                ).get_figure()
                plt.xlabel('world states')
                plt.ylabel('messages')
                plt.title(f'Sender\'s weights, rollout {epoch}')
                plt.savefig(f"images/sender_{epoch}.png")
                plt.clf()

            if epoch % 100 == 0:
                # print(f'Epoch {epoch}, last 100 epochs reward: {past_rewards/100}')
                # print(f"Last State: {stimulus}, Signal: {signal}, Action: {action}, Reward: {reward}")
                history.append(past_rewards/100)
                past_rewards = 0

            if early_stop(7, history, 0.97):
                # print(f'Early stop at epoch {epoch}')
                # stopped_at = epoch
                stopped = True
                break

        if not stopped and history[-1] < 0.8:
            print(f'Possibility of no convergence at seed {seed}')
            print("Making gifs...")
            make_gif(f'{states}-{actions}-{signals}-sender', epochs, seed)
            make_gif(f'{states}-{actions}-{signals}-receiver', epochs, seed)
            print("Observation to message mapping:")
            print(S.signal_weights.argmax(1))
            print("Message to action mapping:")
            print(R.action_weights.argmax(1))
            print("-"*50)
            num_found += 1
            found = True


    if not found:
        print(f'No possibility of no convergence found for {states}-{actions}-{signals} after {n} {epochs}-epoch tries. Try increasing n.')
    print(f'Found {num_found} cases of no convergence, out of {n} trials.')

# %%
stress(1000, 10000, 3, 3, 3, 1)
# Out:
# Possibility of no convergence at seed 1677257243
# Making gifs...
# Observation to message mapping:
# [2 0 2]
# Message to action mapping:
# [1 1 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677257412
# Making gifs...
# Observation to message mapping:
# [1 1 0]
# Message to action mapping:
# [2 0 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677257649
# Making gifs...
# Observation to message mapping:
# [2 1 1]
# Message to action mapping:
# [0 1 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677258505
# Making gifs...
# Observation to message mapping:
# [2 1 0]
# Message to action mapping:
# [2 1 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677258752
# Making gifs...
# Observation to message mapping:
# [1 2 2]
# Message to action mapping:
# [0 0 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677258973
# Making gifs...
# Observation to message mapping:
# [1 1 2]
# Message to action mapping:
# [1 1 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677259107
# Making gifs...
# Observation to message mapping:
# [2 1 1]
# Message to action mapping:
# [1 1 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677259268
# Making gifs...
# Observation to message mapping:
# [0 2 0]
# Message to action mapping:
# [2 1 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677259568
# Making gifs...
# Observation to message mapping:
# [2 1 1]
# Message to action mapping:
# [0 2 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677259778
# Making gifs...
# Observation to message mapping:
# [1 2 2]
# Message to action mapping:
# [0 0 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677259928
# Making gifs...
# Observation to message mapping:
# [1 2 0]
# Message to action mapping:
# [2 0 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677260175
# Making gifs...
# Observation to message mapping:
# [0 1 0]
# Message to action mapping:
# [2 1 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677260339
# Making gifs...
# Observation to message mapping:
# [2 2 0]
# Message to action mapping:
# [2 2 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677260457
# Making gifs...
# Observation to message mapping:
# [0 2 1]
# Message to action mapping:
# [0 2 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677260572
# Making gifs...
# Observation to message mapping:
# [0 0 2]
# Message to action mapping:
# [1 2 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677260945
# Making gifs...
# Observation to message mapping:
# [2 1 2]
# Message to action mapping:
# [1 1 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677261119
# Making gifs...
# Observation to message mapping:
# [1 2 2]
# Message to action mapping:
# [0 0 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677261240
# Making gifs...
# Observation to message mapping:
# [2 0 0]
# Message to action mapping:
# [2 0 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677261477
# Making gifs...
# Observation to message mapping:
# [2 1 0]
# Message to action mapping:
# [2 1 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677261711
# Making gifs...
# Observation to message mapping:
# [1 1 0]
# Message to action mapping:
# [2 1 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677261823
# Making gifs...
# Observation to message mapping:
# [2 0 2]
# Message to action mapping:
# [1 2 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677261967
# Making gifs...
# Observation to message mapping:
# [2 1 1]
# Message to action mapping:
# [0 1 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677262278
# Making gifs...
# Observation to message mapping:
# [2 2 1]
# Message to action mapping:
# [1 2 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677263413
# Making gifs...
# Observation to message mapping:
# [2 1 2]
# Message to action mapping:
# [1 1 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677263526
# Making gifs...
# Observation to message mapping:
# [1 0 0]
# Message to action mapping:
# [2 0 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677263881
# Making gifs...
# Observation to message mapping:
# [0 2 0]
# Message to action mapping:
# [2 1 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677264015
# Making gifs...
# Observation to message mapping:
# [2 0 2]
# Message to action mapping:
# [1 1 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677264422
# Making gifs...
# Observation to message mapping:
# [0 1 2]
# Message to action mapping:
# [2 1 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677264536
# Making gifs...
# Observation to message mapping:
# [2 2 1]
# Message to action mapping:
# [1 2 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677264719
# Making gifs...
# Observation to message mapping:
# [2 0 2]
# Message to action mapping:
# [1 1 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677264906
# Making gifs...
# Observation to message mapping:
# [1 1 2]
# Message to action mapping:
# [0 0 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677265039
# Making gifs...
# Observation to message mapping:
# [0 1 0]
# Message to action mapping:
# [2 1 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677265152
# Making gifs...
# Observation to message mapping:
# [2 0 1]
# Message to action mapping:
# [1 2 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677265453
# Making gifs...
# Observation to message mapping:
# [0 2 0]
# Message to action mapping:
# [0 1 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677265576
# Making gifs...
# Observation to message mapping:
# [0 2 0]
# Message to action mapping:
# [2 1 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677265742
# Making gifs...
# Observation to message mapping:
# [1 2 1]
# Message to action mapping:
# [1 2 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677265866
# Making gifs...
# Observation to message mapping:
# [0 2 0]
# Message to action mapping:
# [0 0 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677265988
# Making gifs...
# Observation to message mapping:
# [1 1 2]
# Message to action mapping:
# [2 1 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677266158
# Making gifs...
# Observation to message mapping:
# [0 0 1]
# Message to action mapping:
# [1 2 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677266570
# Making gifs...
# Observation to message mapping:
# [0 0 1]
# Message to action mapping:
# [1 2 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677266766
# Making gifs...
# Observation to message mapping:
# [2 0 0]
# Message to action mapping:
# [2 0 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677267383
# Making gifs...
# Observation to message mapping:
# [2 0 2]
# Message to action mapping:
# [1 1 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677267571
# Making gifs...
# Observation to message mapping:
# [2 1 2]
# Message to action mapping:
# [1 1 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677268067
# Making gifs...
# Observation to message mapping:
# [0 1 1]
# Message to action mapping:
# [0 1 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677268381
# Making gifs...
# Observation to message mapping:
# [2 1 1]
# Message to action mapping:
# [1 1 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677268727
# Making gifs...
# Observation to message mapping:
# [1 1 0]
# Message to action mapping:
# [2 1 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677269363
# Making gifs...
# Observation to message mapping:
# [1 2 1]
# Message to action mapping:
# [1 2 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677269505
# Making gifs...
# Observation to message mapping:
# [0 0 2]
# Message to action mapping:
# [1 1 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677269681
# Making gifs...
# Observation to message mapping:
# [1 0 2]
# Message to action mapping:
# [2 0 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677269975
# Making gifs...
# Observation to message mapping:
# [2 0 1]
# Message to action mapping:
# [1 2 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677270136
# Making gifs...
# Observation to message mapping:
# [2 2 0]
# Message to action mapping:
# [2 1 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677270248
# Making gifs...
# Observation to message mapping:
# [0 1 0]
# Message to action mapping:
# [0 1 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677270404
# Making gifs...
# Observation to message mapping:
# [1 0 1]
# Message to action mapping:
# [1 0 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677271303
# Making gifs...
# Observation to message mapping:
# [2 1 2]
# Message to action mapping:
# [0 1 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677271434
# Making gifs...
# Observation to message mapping:
# [0 2 2]
# Message to action mapping:
# [0 0 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677271541
# Making gifs...
# Observation to message mapping:
# [2 1 2]
# Message to action mapping:
# [1 1 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677271862
# Making gifs...
# Observation to message mapping:
# [2 0 0]
# Message to action mapping:
# [2 0 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677272020
# Making gifs...
# Observation to message mapping:
# [2 0 0]
# Message to action mapping:
# [2 0 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677272170
# Making gifs...
# Observation to message mapping:
# [0 1 1]
# Message to action mapping:
# [0 1 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677272286
# Making gifs...
# Observation to message mapping:
# [2 1 1]
# Message to action mapping:
# [0 1 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677272396
# Making gifs...
# Observation to message mapping:
# [0 2 0]
# Message to action mapping:
# [2 1 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677272809
# Making gifs...
# Observation to message mapping:
# [1 2 2]
# Message to action mapping:
# [0 0 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677272952
# Making gifs...
# Observation to message mapping:
# [0 2 2]
# Message to action mapping:
# [0 1 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677273059
# Making gifs...
# Observation to message mapping:
# [1 1 0]
# Message to action mapping:
# [2 0 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677273258
# Making gifs...
# Observation to message mapping:
# [2 0 2]
# Message to action mapping:
# [1 1 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677273700
# Making gifs...
# Observation to message mapping:
# [2 1 2]
# Message to action mapping:
# [1 1 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677273922
# Making gifs...
# Observation to message mapping:
# [1 2 2]
# Message to action mapping:
# [0 0 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677274385
# Making gifs...
# Observation to message mapping:
# [0 2 1]
# Message to action mapping:
# [0 1 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677274612
# Making gifs...
# Observation to message mapping:
# [1 2 1]
# Message to action mapping:
# [1 2 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677274863
# Making gifs...
# Observation to message mapping:
# [1 0 1]
# Message to action mapping:
# [1 2 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677274977
# Making gifs...
# Observation to message mapping:
# [1 0 1]
# Message to action mapping:
# [1 0 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677275093
# Making gifs...
# Observation to message mapping:
# [2 2 0]
# Message to action mapping:
# [2 2 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677275480
# Making gifs...
# Observation to message mapping:
# [0 0 1]
# Message to action mapping:
# [0 2 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677276093
# Making gifs...
# Observation to message mapping:
# [1 1 2]
# Message to action mapping:
# [2 1 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677276734
# Making gifs...
# Observation to message mapping:
# [0 2 0]
# Message to action mapping:
# [0 1 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677276905
# Making gifs...
# Observation to message mapping:
# [0 2 2]
# Message to action mapping:
# [0 0 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677277122
# Making gifs...
# Observation to message mapping:
# [2 1 0]
# Message to action mapping:
# [0 1 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677277288
# Making gifs...
# Observation to message mapping:
# [2 2 0]
# Message to action mapping:
# [2 2 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677277989
# Making gifs...
# Observation to message mapping:
# [0 0 2]
# Message to action mapping:
# [0 0 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677278595
# Making gifs...
# Observation to message mapping:
# [2 2 1]
# Message to action mapping:
# [2 2 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677279266
# Making gifs...
# Observation to message mapping:
# [1 0 1]
# Message to action mapping:
# [1 2 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677279631
# Making gifs...
# Observation to message mapping:
# [1 0 0]
# Message to action mapping:
# [2 0 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677279764
# Making gifs...
# Observation to message mapping:
# [2 2 1]
# Message to action mapping:
# [2 2 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677279879
# Making gifs...
# Observation to message mapping:
# [0 1 2]
# Message to action mapping:
# [0 1 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677280307
# Making gifs...
# Observation to message mapping:
# [0 0 1]
# Message to action mapping:
# [0 2 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677280660
# Making gifs...
# Observation to message mapping:
# [1 2 2]
# Message to action mapping:
# [1 0 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677280983
# Making gifs...
# Observation to message mapping:
# [2 1 2]
# Message to action mapping:
# [0 1 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677281125
# Making gifs...
# Observation to message mapping:
# [1 1 0]
# Message to action mapping:
# [2 1 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677281374
# Making gifs...
# Observation to message mapping:
# [0 1 0]
# Message to action mapping:
# [0 1 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677281606
# Making gifs...
# Observation to message mapping:
# [2 0 0]
# Message to action mapping:
# [2 0 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677281925
# Making gifs...
# Observation to message mapping:
# [2 0 0]
# Message to action mapping:
# [1 0 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677282342
# Making gifs...
# Observation to message mapping:
# [0 2 2]
# Message to action mapping:
# [0 0 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677282608
# Making gifs...
# Observation to message mapping:
# [2 0 0]
# Message to action mapping:
# [1 0 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677282840
# Making gifs...
# Observation to message mapping:
# [1 0 2]
# Message to action mapping:
# [0 0 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677283110
# Making gifs...
# Observation to message mapping:
# [2 0 1]
# Message to action mapping:
# [1 0 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677283279
# Making gifs...
# Observation to message mapping:
# [1 2 1]
# Message to action mapping:
# [2 2 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677283592
# Making gifs...
# Observation to message mapping:
# [1 2 2]
# Message to action mapping:
# [0 0 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677283947
# Making gifs...
# Observation to message mapping:
# [2 2 1]
# Message to action mapping:
# [2 2 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677284138
# Making gifs...
# Observation to message mapping:
# [2 1 1]
# Message to action mapping:
# [0 2 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677284889
# Making gifs...
# Observation to message mapping:
# [1 1 2]
# Message to action mapping:
# [2 0 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677285054
# Making gifs...
# Observation to message mapping:
# [2 0 1]
# Message to action mapping:
# [1 2 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677285760
# Making gifs...
# Observation to message mapping:
# [2 1 2]
# Message to action mapping:
# [2 1 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677285957
# Making gifs...
# Observation to message mapping:
# [1 2 0]
# Message to action mapping:
# [2 2 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677286690
# Making gifs...
# Observation to message mapping:
# [0 0 2]
# Message to action mapping:
# [1 2 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677286900
# Making gifs...
# Observation to message mapping:
# [0 2 0]
# Message to action mapping:
# [2 1 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677287191
# Making gifs...
# Observation to message mapping:
# [1 2 2]
# Message to action mapping:
# [0 0 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677287575
# Making gifs...
# Observation to message mapping:
# [2 1 2]
# Message to action mapping:
# [2 1 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677287769
# Making gifs...
# Observation to message mapping:
# [0 0 1]
# Message to action mapping:
# [0 2 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677287902
# Making gifs...
# Observation to message mapping:
# [0 1 0]
# Message to action mapping:
# [0 1 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677288065
# Making gifs...
# Observation to message mapping:
# [1 1 2]
# Message to action mapping:
# [2 1 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677288204
# Making gifs...
# Observation to message mapping:
# [2 0 2]
# Message to action mapping:
# [1 1 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677288600
# Making gifs...
# Observation to message mapping:
# [0 2 2]
# Message to action mapping:
# [0 0 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677288751
# Making gifs...
# Observation to message mapping:
# [1 1 0]
# Message to action mapping:
# [2 1 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677289053
# Making gifs...
# Observation to message mapping:
# [1 1 0]
# Message to action mapping:
# [2 0 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677289171
# Making gifs...
# Observation to message mapping:
# [0 2 2]
# Message to action mapping:
# [0 0 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677289304
# Making gifs...
# Observation to message mapping:
# [2 1 2]
# Message to action mapping:
# [2 1 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677290080
# Making gifs...
# Observation to message mapping:
# [2 2 0]
# Message to action mapping:
# [2 2 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677290240
# Making gifs...
# Observation to message mapping:
# [0 1 0]
# Message to action mapping:
# [0 1 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677290759
# Making gifs...
# Observation to message mapping:
# [0 0 2]
# Message to action mapping:
# [1 0 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677291237
# Making gifs...
# Observation to message mapping:
# [1 0 0]
# Message to action mapping:
# [2 0 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677291631
# Making gifs...
# Observation to message mapping:
# [2 0 2]
# Message to action mapping:
# [1 1 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677291865
# Making gifs...
# Observation to message mapping:
# [0 2 2]
# Message to action mapping:
# [0 1 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677292183
# Making gifs...
# Observation to message mapping:
# [2 0 0]
# Message to action mapping:
# [1 0 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677292485
# Making gifs...
# Observation to message mapping:
# [0 2 2]
# Message to action mapping:
# [0 0 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677292712
# Making gifs...
# Observation to message mapping:
# [2 1 2]
# Message to action mapping:
# [2 1 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677293324
# Making gifs...
# Observation to message mapping:
# [2 2 1]
# Message to action mapping:
# [1 2 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677293502
# Making gifs...
# Observation to message mapping:
# [1 2 2]
# Message to action mapping:
# [0 0 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677293886
# Making gifs...
# Observation to message mapping:
# [2 1 2]
# Message to action mapping:
# [1 1 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677294601
# Making gifs...
# Observation to message mapping:
# [0 2 2]
# Message to action mapping:
# [0 0 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677294722
# Making gifs...
# Observation to message mapping:
# [2 1 2]
# Message to action mapping:
# [1 1 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677294864
# Making gifs...
# Observation to message mapping:
# [2 2 0]
# Message to action mapping:
# [2 2 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677295199
# Making gifs...
# Observation to message mapping:
# [0 0 1]
# Message to action mapping:
# [1 2 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677295334
# Making gifs...
# Observation to message mapping:
# [0 1 1]
# Message to action mapping:
# [0 2 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677295480
# Making gifs...
# Observation to message mapping:
# [1 1 2]
# Message to action mapping:
# [2 1 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677296029
# Making gifs...
# Observation to message mapping:
# [0 1 0]
# Message to action mapping:
# [2 1 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677296492
# Making gifs...
# Observation to message mapping:
# [0 1 1]
# Message to action mapping:
# [0 1 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677296972
# Making gifs...
# Observation to message mapping:
# [1 0 0]
# Message to action mapping:
# [2 0 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677297097
# Making gifs...
# Observation to message mapping:
# [1 0 2]
# Message to action mapping:
# [1 0 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677297452
# Making gifs...
# Observation to message mapping:
# [0 0 2]
# Message to action mapping:
# [1 2 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677297694
# Making gifs...
# Observation to message mapping:
# [0 1 0]
# Message to action mapping:
# [0 1 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677297907
# Making gifs...
# Observation to message mapping:
# [0 0 1]
# Message to action mapping:
# [1 2 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677298070
# Making gifs...
# Observation to message mapping:
# [0 2 0]
# Message to action mapping:
# [0 1 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677298328
# Making gifs...
# Observation to message mapping:
# [2 1 2]
# Message to action mapping:
# [0 1 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677298444
# Making gifs...
# Observation to message mapping:
# [1 0 1]
# Message to action mapping:
# [1 0 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677298662
# Making gifs...
# Observation to message mapping:
# [1 2 1]
# Message to action mapping:
# [1 0 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677298780
# Making gifs...
# Observation to message mapping:
# [0 0 1]
# Message to action mapping:
# [1 2 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677299617
# Making gifs...
# Observation to message mapping:
# [2 1 1]
# Message to action mapping:
# [1 1 0]
# --------------------------------------------------
# Possibility of no convergence at seed 1677299737
# Making gifs...
# Observation to message mapping:
# [1 0 0]
# Message to action mapping:
# [1 0 1]
# --------------------------------------------------
# Possibility of no convergence at seed 1677300142
# Making gifs...
# Observation to message mapping:
# [0 0 2]
# Message to action mapping:
# [0 0 2]
# --------------------------------------------------
# Possibility of no convergence at seed 1677300399
# Making gifs...
# Observation to message mapping:
# [1 2 2]
# Message to action mapping:
# [0 0 1]
# --------------------------------------------------
# Found 150 cases of no convergence, out of 1000 trials.

# %% [markdown]
# Found 150 possible cases after 1000 trials, and manually checked each 150 for patterns and false positives.

# %%
x = len(list(os.listdir('./gifs')))
print(f"Number of cases remaining: {x}")
print(f"Final ratio: {(x/1000)*100}% of cases did not converge.")
# Out:
# Number of cases remaining: 113
# Final ratio: 11.3% of cases did not converge.

# %% [markdown]
# ## Examples:

# %% [markdown]
# ### Case: Sender Error
# Seed 1677283110
#
#
# ![Sender](./1677283110/3-3-3-sender.gif) ![Receiver](./1677283110/3-3-3-receiver.gif)

# %% [markdown]
# ### Case: Reciever Error
# These cases are not as well defined, and could trend towards convergence on a very improbable random chance
#
# Seed 1677289304
#
# ![Sender](./1677289304/3-3-3-sender.gif) ![Receiver](./1677289304/3-3-3-receiver.gif)

# %% [markdown]
# ### Case: Cooperative Error
# Most common.
#
# Seed 1677258752
#
# ![Sender](./1677258752/3-3-3-sender.gif) ![Receiver](./1677258752/3-3-3-receiver.gif)
#
# Seed 1677281374
#
# ![Sender](./1677281374/3-3-3-sender.gif) ![Receiver](./1677281374/3-3-3-receiver.gif)

# %% [markdown]
# ### Case: Colorful or Odd
# These often fit under another category or are more likely to trend towards convergence than other member of that category, but maintain a unique look thoughout the 10,000 rollouts.
#
# Seed 1677271434
#
# ![Sender](./1677271434/3-3-3-sender.gif) ![Receiver](./1677271434/3-3-3-receiver.gif)
#
# Seed 1677261711
#
# ![Sender](./1677261711/3-3-3-sender.gif) ![Receiver](./1677261711/3-3-3-receiver.gif)
